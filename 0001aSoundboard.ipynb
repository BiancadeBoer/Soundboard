# %%
import tkinter as tk
import pygame.mixer
import tkinter.font as tkFont

class SoundboardApp:
    def __init__(self, master):
        self.master = master
        self.master.title("Soundboard App by Bianca de Boer")
        self.master.geometry("600x450")
        
 # Set background color to black
        self.master.configure(bg="black")


 # Initialize Pygame mixer
        pygame.mixer.init()

 # Load sound files
        self.sound1 = pygame.mixer.Sound("2023.wav")
        self.sound2 = pygame.mixer.Sound("Boiing.wav")
        self.sound3 = pygame.mixer.Sound("damnyou.wav")
        self.sound4 = pygame.mixer.Sound("doorbang.wav")
        self.sound5 = pygame.mixer.Sound("giggle.wav")
        self.sound6 = pygame.mixer.Sound("gof_you.wav")
        self.sound7 = pygame.mixer.Sound("Hahn.wav")
        self.sound8 = pygame.mixer.Sound("kiss.wav")
        self.sound9 = pygame.mixer.Sound("lachen.wav")
        self.sound10 = pygame.mixer.Sound("Lalalaaa.wav")
        self.sound11 = pygame.mixer.Sound("letsgo.wav")
        self.sound12 = pygame.mixer.Sound("pussi.wav")
        self.sound13 = pygame.mixer.Sound("sigh.wav")
        self.sound14 = pygame.mixer.Sound("Mooeep.wav")
        self.sound15 = pygame.mixer.Sound("Mimimi.wav")
        self.sound16 = pygame.mixer.Sound("tada.wav")
        self.sound17 = pygame.mixer.Sound("whistle.wav")
        self.sound18 = pygame.mixer.Sound("wilhelmsschrei.wav")
        self.sound19 = pygame.mixer.Sound("woyaya_whistle.wav")
        self.sound20 = pygame.mixer.Sound("Jeopardy_Music.wav")
        self.sound21 = pygame.mixer.Sound("cantina.wav")
        self.sound22 = pygame.mixer.Sound("whip2.wav")
        self.sound23 = pygame.mixer.Sound("Tetris.wav")
       
       
# Create buttons for each sound
        button_font=tkFont.Font(family='helvetica', size= 12)
        self.button1 = tk.Button(self.master, text="2023", bg="green", fg="white",font=button_font, command=self.play_sound1)
        self.button1.grid(row=0,column=0, padx='5', pady='5', sticky='ew')
        self.button2 = tk.Button(self.master, text="Boing",  bg="green", fg="white",font=button_font,command=self.play_sound2)
        self.button2.grid(row=1,column=0, padx='5', pady='5', sticky='ew')
        self.button3 = tk.Button(self.master, text="Damn", bg="green", fg="white",font=button_font, command=self.play_sound3)
        self.button3.grid(row=2,column=0, padx='5', pady='5', sticky='ew')
        self.button4 = tk.Button(self.master, text="Klopfen", bg="green", fg="white",font=button_font, command=self.play_sound4)
        self.button4.grid(row=3,column=0, padx='5', pady='5', sticky='ew')
        self.button5 = tk.Button(self.master, text="Giggle",  bg="green", fg="white",font=button_font,command=self.play_sound5)
        self.button5.grid(row=4,column=0, padx='5', pady='5', sticky='ew')
        self.button6 = tk.Button(self.master, text="Fuck",  bg="green", fg="white",font=button_font,command=self.play_sound6)
        self.button6.grid(row=0,column=1, padx='5', pady='5', sticky='ew')
        self.button7 = tk.Button(self.master, text="Hahn", bg="green", fg="white", font=button_font,command=self.play_sound7)
        self.button7.grid(row=1,column=1, padx='5', pady='5', sticky='ew')
        self.button8 = tk.Button(self.master, text="Kiss", bg="green", fg="white",font=button_font, command=self.play_sound8)
        self.button8.grid(row=2,column=1, padx='5', pady='5', sticky='ew')
        self.button9 = tk.Button(self.master, text="Lachen", bg="green", fg="white",font=button_font, command=self.play_sound9)
        self.button9.grid(row=3,column=1, padx='5', pady='5', sticky='ew')
        self.button10 = tk.Button(self.master, text="Lalalaaa", bg="green", fg="white",font=button_font, command=self.play_sound10)
        self.button10.grid(row=4,column=1, padx='5', pady='5', sticky='ew')
        self.button11 = tk.Button(self.master, text="Let´s go!", bg="green", fg="white",font=button_font, command=self.play_sound11)
        self.button11.grid(row=0,column=2, padx='5', pady='5', sticky='ew')
        self.button12 = tk.Button(self.master, text="Pussi", bg="green", fg="white",font=button_font, command=self.play_sound12)
        self.button12.grid(row=1,column=2, padx='5', pady='5', sticky='ew')
        self.button13 = tk.Button(self.master, text="Seufz", bg="green", fg="white",font=button_font, command=self.play_sound13)
        self.button13.grid(row=2,column=2, padx='5', pady='5', sticky='ew')
        self.button14 = tk.Button(self.master, text="Möööp", bg="green", fg="white",font=button_font, command=self.play_sound14)
        self.button14.grid(row=3,column=2, padx='5', pady='5', sticky='ew')
        self.button15 = tk.Button(self.master, text="Mimimi", bg="green", fg="white", font=button_font,command=self.play_sound15)
        self.button15.grid(row=4,column=2, padx='5', pady='5', sticky='ew')
        self.button16 = tk.Button(self.master, text="Tadaaa", bg="green", fg="white",font=button_font, command=self.play_sound16)
        self.button16.grid(row=0,column=3, padx='5', pady='5', sticky='ew')
        self.button17 = tk.Button(self.master, text="Whistle", bg="green", fg="white",font=button_font, command=self.play_sound17)
        self.button17.grid(row=1,column=3, padx='5', pady='5', sticky='ew')
        self.button18 = tk.Button(self.master, text="Wilhelmsschrei", bg="green", fg="white", font=button_font,command=self.play_sound18)
        self.button18.grid(row=2,column=3, padx='5', pady='5', sticky='ew')
        self.button19 = tk.Button(self.master, text="Woyaya Whistle", bg="green", fg="white", font=button_font,command=self.play_sound19)
        self.button19.grid(row=3,column=3, padx='5', pady='5', sticky='ew')
        self.button20 = tk.Button(self.master, text="Jeopardy", bg="green", fg="white",font=button_font, command=self.play_sound20)
        self.button20.grid(row=4,column=3, padx='5', pady='5', sticky='ew')
        self.button21 = tk.Button(self.master, text="Cantina", bg="green", fg="white",font=button_font, command=self.play_sound21)
        self.button21.grid(row=0,column=4, padx='5', pady='5', sticky='ew')
        self.button22 = tk.Button(self.master, text="Peitsche", bg="green", fg="white",font=button_font, command=self.play_sound22)
        self.button22.grid(row=1,column=4, padx='5', pady='5', sticky='ew')
        self.button23 = tk.Button(self.master, text="Tetris", bg="green", fg="white",font=button_font, command=self.play_sound23)
        self.button23.grid(row=2,column=4, padx='5', pady='5', sticky='ew')
        
 # Create button to stop all sounds
        self.stop_button = tk.Button(self.master, text="Stop all sounds", bg="red", fg="white", font=button_font, command=self.stop_all_sounds)
        self.stop_button.grid(row=5,column=2, padx='5', pady='5', sticky='ew')
        
# Store active sounds
        self.active_sounds = []

    def play_sound1(self):
        sound=self.sound1.play()
        self.active_sounds.append(sound)

    def play_sound2(self):
        sound=self.sound2.play()
        self.active_sounds.append(sound)

    def play_sound3(self):
        sound=self.sound3.play()
        self.active_sounds.append(sound)
        
    def play_sound4(self):
        sound=self.sound4.play()
        self.active_sounds.append(sound) 
           
    def play_sound5(self):
        sound=self.sound5.play()
        self.active_sounds.append(sound)
            
    def play_sound6(self):
        sound=self.sound6.play()
        self.active_sounds.append(sound) 
           
    def play_sound7(self):
        sound=self.sound7.play()
        self.active_sounds.append(sound) 
           
    def play_sound8(self):
        sound=self.sound8.play() 
        self.active_sounds.append(sound)
           
    def play_sound9(self):
        sound=self.sound9.play() 
        self.active_sounds.append(sound) 
          
    def play_sound10(self):
        sound=self.sound10.play()
        self.active_sounds.append(sound) 
           
    def play_sound11(self):
        sound=self.sound11.play()
        self.active_sounds.append(sound) 
        
    def play_sound12(self):
        sound=self.sound12.play() 
        self.active_sounds.append(sound)  
         
    def play_sound13(self):
        sound=self.sound13.play() 
        self.active_sounds.append(sound)
           
    def play_sound14(self):
        sound=self.sound14.play() 
        self.active_sounds.append(sound)
           
    def play_sound15(self):
        sound=self.sound15.play() 
        self.active_sounds.append(sound) 
          
    def play_sound16(self):
        sound=self.sound16.play() 
        self.active_sounds.append(sound)
           
    def play_sound17(self):
        sound=self.sound17.play()
        self.active_sounds.append(sound)
            
    def play_sound18(self):
        sound=self.sound18.play()
        self.active_sounds.append(sound)
            
    def play_sound19(self):
        sound=self.sound19.play()
        self.active_sounds.append(sound)
        
    def play_sound20(self):
        sound=self.sound20.play()
        self.active_sounds.append(sound)
        
    def play_sound21(self):
        sound=self.sound21.play()
        self.active_sounds.append(sound)
        
    def play_sound22(self):
        sound=self.sound22.play()
        self.active_sounds.append(sound)
            
    def play_sound23(self):
        sound=self.sound23.play() 
        self.active_sounds.append(sound)
        
    def stop_all_sounds(self):
        for sound in self.active_sounds:
            sound.stop()
        self.active_sounds = [] 
         

if __name__ == '__main__':
    root = tk.Tk()
    app = SoundboardApp(root)
    root.mainloop()
